# %% [markdown]
# # MODULO 04 - PREPARAÇÃO DE DADOS

# %%
# BIBLIOTECAS IMPORTANTES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime
import unicodedata

pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 160)

# %%
# Estrutura padrão do projeto
RAIZ = Path.cwd().parent.resolve()
PASTAS = [
 "dados_brutos", "dados_tratados", "docs",
 "notebooks", "sql", "dashboards", "resultados",
 "relatorios", "apresentacao", "logs"
]
for pasta in PASTAS:
 (RAIZ / pasta).mkdir(
 parents=True, exist_ok=True)

print("Pastas verificadas/criadas:")
for pasta in PASTAS:
 print("-", RAIZ / pasta)
# Out:
# Pastas verificadas/criadas:
# - /workspaces/FAP-2026-AnaliseDados-Python/dados_brutos
# - /workspaces/FAP-2026-AnaliseDados-Python/dados_tratados
# - /workspaces/FAP-2026-AnaliseDados-Python/docs
# - /workspaces/FAP-2026-AnaliseDados-Python/notebooks
# - /workspaces/FAP-2026-AnaliseDados-Python/sql
# - /workspaces/FAP-2026-AnaliseDados-Python/dashboards
# - /workspaces/FAP-2026-AnaliseDados-Python/resultados
# - /workspaces/FAP-2026-AnaliseDados-Python/relatorios
# - /workspaces/FAP-2026-AnaliseDados-Python/apresentacao
# - /workspaces/FAP-2026-AnaliseDados-Python/logs

# %%
ARQUIVO_BRUTO = Path(
 "dados_brutos/acidentes2025.csv")
ARQUIVO_BASE_ANALITICA = Path(
 "dados_tratados/base_analitica_prf_2025.csv")
ARQUIVO_BASE_MODELAVEL = Path(
 "dados_tratados/base_modelavel_prf_2025.csv")
ARQUIVO_DICIONARIO = Path(
 "dados_tratados/dicionario_variaveis_modulo4.csv")
ARQUIVO_DECISOES = Path(
 "logs/decisoes_tratamento_modulo4.md")
ARQUIVO_README = Path("README.md")

SEPARADOR = ";"
ENCODING_ENTRADA = "latin1"
ENCODING_SAIDA = "utf-8-sig"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ARQUIVO_BRUTO = Path(
#       2  "dados_brutos/acidentes2025.csv")
#       3 ARQUIVO_BASE_ANALITICA = Path(
#       4  "dados_tratados/base_analitica_prf_2025.csv")
#       5 ARQUIVO_BASE_MODELAVEL = Path(
#       6  "dados_tratados/base_modelavel_prf_2025.csv")
#
# NameError: name 'Path' is not defined
